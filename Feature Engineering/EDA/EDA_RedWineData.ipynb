# %%
# Fetching Wine Quality dataset from UCI machine learning repository
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine_quality = fetch_ucirepo(id=186) 
  
# data (as pandas dataframes) 
X = wine_quality.data.features 
y = wine_quality.data.targets 
  
# metadata 
print(wine_quality.metadata) 
  
# variable information 
print(wine_quality.variables)
# Out:
# {'uci_id': 186, 'name': 'Wine Quality', 'repository_url': 'https://archive.ics.uci.edu/dataset/186/wine+quality', 'data_url': 'https://archive.ics.uci.edu/static/public/186/data.csv', 'abstract': 'Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests (see [Cortez et al., 2009], http://www3.dsi.uminho.pt/pcortez/wine/).', 'area': 'Business', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Multivariate'], 'num_instances': 4898, 'num_features': 11, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['quality'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2009, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C56S3T', 'creators': ['Paulo Cortez', 'A. Cerdeira', 'F. Almeida', 'T. Matos', 'J. Reis'], 'intro_paper': {'title': 'Modeling wine preferences by data mining from physic
# ...

# %%
# covert y to dataframe
import pandas as pd
df1 = pd.DataFrame(y)
df2 = pd.DataFrame(X)

# %%
df1.dtypes
# Out:
# quality    int64
# dtype: object

# %%
# make it a pandas dataframe

df_winequality = pd.concat([df1,df2],axis=1)

# %%
df_winequality.head()
# Out:
#    quality  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        6            7.0              0.27         0.36            20.7
# 1        6            6.3              0.30         0.34             1.6
# 2        6            8.1              0.28         0.40             6.9
# 3        6            7.2              0.23         0.32             8.5
# 4        6            7.2              0.23         0.32             8.5
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol
# 0       0.45      8.8
# 1       0.49      9.5
# 2       0.44     10.1
# ...

# %%
# shape of dataset
df_winequality.shape
# Out:
# (4898, 12)

# %%
# Summary of dataset
df_winequality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   quality               4898 non-null   int64
#  1   fixed_acidity         4898 non-null   float64
#  2   volatile_acidity      4898 non-null   float64
#  3   citric_acid           4898 non-null   float64
#  4   residual_sugar        4898 non-null   float64
#  5   chlorides             4898 non-null   float64
#  6   free_sulfur_dioxide   4898 non-null   float64
#  7   total_sulfur_dioxide  4898 non-null   float64
#  8   density               4898 non-null   float64
#  9   pH                    4898 non-null   float64
#  10  sulphates             4898 non-null   float64
#  11  alcohol               4898 non-null   float64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# descriptive stats
df_winequality.describe()
# Out:
#            quality  fixed_acidity  volatile_acidity  citric_acid  \
# count  4898.000000    4898.000000       4898.000000  4898.000000
# mean      5.877909       6.854788          0.278241     0.334192
# std       0.885639       0.843868          0.100795     0.121020
# min       3.000000       3.800000          0.080000     0.000000
# 25%       5.000000       6.300000          0.210000     0.270000
# 50%       6.000000       6.800000          0.260000     0.320000
# 75%       6.000000       7.300000          0.320000     0.390000
# max       9.000000      14.200000          1.100000     1.660000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     4898.000000  4898.000000          4898.000000           4898.000000
# mean         6.391415     0.045772            35.308085            138.360657
# std          5.072058     0.021848            17.007137             42.498065
# ...

# %%
# list all column
df_winequality.columns
# Out:
# Index(['quality', 'fixed_acidity', 'volatile_acidity', 'citric_acid',
#        'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
#        'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
df_winequality['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
# Conclusion -- Imbalanced Dataset
df_winequality['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
# no missing Values
df_winequality.isnull().sum()
# Out:
# quality                 0
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# dtype: int64

# %%
# to check duplicate records
df_winequality[df_winequality.duplicated()]
# Out:
#       quality  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 4           6            7.2              0.23         0.32             8.5
# 5           6            8.1              0.28         0.40             6.9
# 7           6            7.0              0.27         0.36            20.7
# 8           6            6.3              0.30         0.34             1.6
# 20          8            6.2              0.66         0.48             1.2
# ...       ...            ...               ...          ...             ...
# 4828        5            6.4              0.23         0.35            10.3
# 4850        6            7.0              0.36         0.35             2.5
# 4851        5            6.4              0.33         0.44             8.9
# 4856        6            7.1              0.23         0.39            13.7
# 4880        6            6.6              0.34         0.40             8.1
#
# ...

# %%
# remove duplicate records
df_winequality =  df_winequality.drop_duplicates()

# %%
# correlation
df_winequality.corr()
# Out:
#                        quality  fixed_acidity  volatile_acidity  citric_acid  \
# quality               1.000000      -0.124636         -0.190678     0.007065
# fixed_acidity        -0.124636       1.000000         -0.019214     0.298959
# volatile_acidity     -0.190678      -0.019214          1.000000    -0.163228
# citric_acid           0.007065       0.298959         -0.163228     1.000000
# residual_sugar       -0.117339       0.083620          0.098340     0.106269
# chlorides            -0.217739       0.024036          0.086287     0.132590
# free_sulfur_dioxide   0.010507      -0.058396         -0.102471     0.091681
# total_sulfur_dioxide -0.183356       0.082425          0.102315     0.122845
# density              -0.337805       0.266091          0.060603     0.160076
# pH                    0.123829      -0.431274         -0.046954    -0.183015
# sulphates             0.053200      -0.017453         -0.021150     0.049442
# ...

# %%
# lets plot this correlation
import matplotlib.pyplot as plt
import seaborn as sbn
plt.figure(figsize=(10,6))
sbn.heatmap(df_winequality.corr(),annot=True)
# Out:
# <Axes: >

# %%
# lets see distribution of quality
df_winequality['quality'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# lets see distribution of fixed acidity
sbn.displot(df_winequality['fixed_acidity'])

# %%
sbn.histplot(df_winequality['fixed_acidity'],kde = True)
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Count'>

# %%
## Categorical plot
sbn.catplot(data = df_winequality,x = 'quality',y = 'alcohol',kind='box')

# %%
# relation between alcohol and ph
sbn.scatterplot(data =df_winequality,x = 'alcohol',y = 'pH',hue = 'quality')
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
